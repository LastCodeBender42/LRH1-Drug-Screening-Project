# %% [markdown]
# <a href="https://colab.research.google.com/github/LastCodeBender42/LRH1-Drug-Screening-Project/blob/main/04_PSN_with_py3dmol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install Bio

import pandas as pd
from Bio.PDB import PDBParser

def pdb_to_dataframe(pdb_file):
    parser = PDBParser(QUIET=True)
    structure = parser.get_structure('structure', pdb_file)

    data = []
    for model in structure:
        for chain in model:
            for residue in chain:
                for atom in residue:
                    data.append([
                        model.id,
                        chain.id,
                        residue.id[1],
                        residue.resname,
                        atom.name,
                        atom.coord[0],
                        atom.coord[1],
                        atom.coord[2],
                        atom.occupancy,
                        atom.bfactor
                    ])

    columns = [
        'Model', 'Chain', 'Residue_Number', 'Residue_Name',
        'Atom_Name', 'X', 'Y', 'Z', 'Occupancy', 'B_Factor'
    ]

    df = pd.DataFrame(data, columns=columns)
    return df

pdb_file = '/content/drive/My Drive/LRH1-Drug-Screening/data/1yok.pdb'
pdb_df = pdb_to_dataframe(pdb_file)
pdb_df
# Out:
#       Model Chain  Residue_Number Residue_Name Atom_Name          X  \
# 0         0     A             300          SER         N  28.985001
# 1         0     A             300          SER        CA  27.739000
# 2         0     A             300          SER         C  27.105000
# 3         0     A             300          SER         O  27.492001
# 4         0     A             300          SER        CB  28.028999
# ...     ...   ...             ...          ...       ...        ...
# 2589      0     N               1          UNK         I  26.409000
# 2590      0     N               1          UNK         S  30.770000
# 2591      0     N               1          UNK         H  23.517000
# 2592      0     N               1          UNK        HN  34.470001
# 2593      0     N               1          UNK        HO  24.819000
#
#               Y          Z  Occupancy  B_Factor
# 0     54.266998  34.372002        1.0     88.63
# 1     54.654999  33.648998        1.0     88.62
# 2     53.480999  32.896999        1.0     89.53
# 3     53.158001  31.774000        1.0     90.12
# 4     55.799000  32.671001        1.0     87.83
# ...         ...        ...        ...       ...
# 2589  23.811001  36.709000        0.0      0.00
# 2590  21.639999  30.334999        0.0      0.00
# 2591  23.597000  28.778000        0.0      0.00
# 2592  26.077999  34.348999        1.0      0.00
# 2593  25.201000  36.011002        1.0      0.00
#
# [2594 rows x 10 columns]

# %%
pdb_1yok_df = pdb_df[(pdb_df['Chain'] == 'A') & (pdb_df['Atom_Name'] == 'CA')]
pdb_1yok_df
# Out:
#       Model Chain  Residue_Number Residue_Name Atom_Name          X  \
# 1         0     A             300          SER        CA  27.739000
# 11        0     A             301          ILE        CA  25.391001
# 20        0     A             302          PRO        CA  22.995001
# 27        0     A             303          HIS        CA  19.211000
# 40        0     A             304          LEU        CA  18.423000
# ...     ...   ...             ...          ...       ...        ...
# 2275      0     A             534          GLU        CA  12.484000
# 2285      0     A             535          MET        CA  14.043000
# 2294      0     A             536          LEU        CA  16.486000
# 2303      0     A             537          HIS        CA  13.362000
# 2316      0     A             538          ALA        CA  12.497000
#
#               Y          Z  Occupancy  B_Factor
# 1     54.654999  33.648998        1.0     88.62
# 11    51.723999  32.971001        1.0     89.13
# 20    52.351002  30.025000        1.0     89.52
# 27    52.382999  30.504000        1.0     89.12
# 40    48.929001  29.101999        1.0     80.76
# ...         ...        ...        ...       ...
# 2275  16.013000  26.959000        1.0     61.83
# 2285  19.150000  25.462000        1.0     62.54
# 2294  17.191999  23.264000        1.0     64.67
# 2303  15.448000  21.931999        1.0     71.70
# 2316  18.066999  19.268999        1.0     78.09
#
# [236 rows x 10 columns]

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Specify the path to your tab-separated file
tsv_file = '/content/drive/My Drive/LRH1-Drug-Screening/data/1yok.cif_ringEdges'

# Read the tab-separated file into a DataFrame
df = pd.read_csv(tsv_file, sep='\t')
df
# Out:
#          NodeId1  Interaction      NodeId2  Distance   Angle  Energy Atom1  \
# 0    A:300:_:SER    VDW:MC_SC  A:488:_:ASN     3.976     NaN     6.0     C
# 1    A:301:_:ILE    VDW:SC_SC  A:305:_:ILE     3.655     NaN     6.0   CG2
# 2    A:301:_:ILE    VDW:SC_SC  A:306:_:LEU     3.774     NaN     6.0    CB
# 3    A:301:_:ILE    VDW:SC_SC  A:446:_:ARG     3.918     NaN     6.0   CD1
# 4    A:302:_:PRO    VDW:SC_SC  A:305:_:ILE     4.186     NaN     6.0    CB
# ..           ...          ...          ...       ...     ...     ...   ...
# 425  C:745:_:LEU    VDW:MC_SC  C:748:_:LEU     4.197     NaN     6.0     C
# 426  C:745:_:LEU    VDW:MC_SC  C:749:_:LEU     3.788     NaN     6.0     C
# 427  C:746:_:ARG  HBOND:SC_SC  C:750:_:ASP     3.383  17.538    17.0    NE
# 428  C:747:_:TYR  HBOND:SC_SC  C:751:_:LYS     3.541  48.081    17.0    OH
# 429  C:748:_:LEU    VDW:MC_SC  C:751:_:LYS     4.188     NaN     6.0     C
#
#     Atom2        Donor Positive Cation Orientation  Model
# 0     ND2          NaN      NaN    NaN         NaN      1
# 1     CG2          NaN      NaN    NaN         NaN      1
# 2     CD2          NaN      NaN    NaN         NaN      1
# 3      CD          NaN      NaN    NaN         NaN      1
# 4     CD1          NaN      NaN    NaN         NaN      1
# ..    ...          ...      ...    ...         ...    ...
# 425    CB          NaN      NaN    NaN         NaN      1
# 426   CD2          NaN      NaN    NaN         NaN      1
# 427   OD2  C:746:_:ARG      NaN    NaN         NaN      1
# 428    NZ  C:747:_:TYR      NaN    NaN         NaN      1
# 429    CG          NaN      NaN    NaN         NaN      1
#
# [430 rows x 13 columns]

# %%
filtered_df = df[df['NodeId1'].str.contains('^A:') & (df['NodeId2'].str.contains('^A:'))].copy()
filtered_df['source'] = filtered_df['NodeId1'].str.extract(r'(\d+)').astype(int)
filtered_df['target'] = filtered_df['NodeId2'].str.extract(r'(\d+)').astype(int)
ring_1yok_df = filtered_df[['source','target']]
ring_1yok_df
# Out:
#      source  target
# 0       300     488
# 1       301     305
# 2       301     306
# 3       301     446
# 4       302     305
# ..      ...     ...
# 393     531     534
# 394     531     535
# 397     532     535
# 399     533     536
# 400     533     537
#
# [353 rows x 2 columns]

# %%
# Merge df1 and df2 on 'ID' column
merged_df = pd.merge(ring_1yok_df, pdb_1yok_df[['Residue_Number', 'X', 'Y', 'Z']], left_on='source', right_on='Residue_Number', how='left')
merged_df.rename(columns={'X': 'X1','Y': 'Y1','Z': 'Z1'}, inplace=True)

merged_df2 = pd.merge(merged_df, pdb_1yok_df[['Residue_Number', 'X', 'Y', 'Z']], left_on='target', right_on='Residue_Number', how='left')
merged_df2.rename(columns={'X': 'X2','Y': 'Y2','Z': 'Z2'}, inplace=True)

edgelist_1yok_coords = merged_df2[['source','target','X1','Y1','Z1','X2','Y2','Z2']]
edgelist_1yok_coords
# Out:
#      source  target         X1         Y1         Z1         X2         Y2  \
# 0       300     488  27.739000  54.654999  33.648998  33.227001  51.904999
# 1       301     305  25.391001  51.723999  32.971001  21.167999  47.055000
# 2       301     306  25.391001  51.723999  32.971001  19.785000  48.264999
# 3       301     446  25.391001  51.723999  32.971001  26.351000  43.930000
# 4       302     305  22.995001  52.351002  30.025000  21.167999  47.055000
# ..      ...     ...        ...        ...        ...        ...        ...
# 348     531     534  13.546000  17.743000  31.415001  12.484000  16.013000
# 349     531     535  13.546000  17.743000  31.415001  14.043000  19.150000
# 350     532     535  16.796000  17.937000  29.448999  14.043000  19.150000
# 351     533     536  16.033001  14.732000  27.562000  16.486000  17.191999
# 352     533     537  16.033001  14.732000  27.562000  13.362000  15.448000
#
#             Z2
# 0    30.902000
# 1    30.945000
# 2    34.279999
# 3    32.924000
# 4    30.945000
# ..         ...
# 348  26.959000
# 349  25.462000
# 350  25.462000
# 351  23.264000
# 352  21.931999
#
# [353 rows x 8 columns]

# %%
# import pandas as pd
# from Bio.PDB import PDBParser

def pdb_to_dataframe(pdb_file):
    parser = PDBParser(QUIET=True)
    structure = parser.get_structure('structure', pdb_file)

    data = []
    for model in structure:
        for chain in model:
            for residue in chain:
                for atom in residue:
                    data.append([
                        model.id,
                        chain.id,
                        residue.id[1],
                        residue.resname,
                        atom.name,
                        atom.coord[0],
                        atom.coord[1],
                        atom.coord[2],
                        atom.occupancy,
                        atom.bfactor
                    ])

    columns = [
        'Model', 'Chain', 'Residue_Number', 'Residue_Name',
        'Atom_Name', 'X', 'Y', 'Z', 'Occupancy', 'B_Factor'
    ]

    df = pd.DataFrame(data, columns=columns)
    return df

# Example usage:
pdb_file = '/content/drive/My Drive/LRH1-Drug-Screening/data/4pld.pdb'
df = pdb_to_dataframe(pdb_file)
df
# Out:
#       Model Chain  Residue_Number Residue_Name Atom_Name          X       Y  \
# 0         0     A             300          SER         N -33.840000 -10.761
# 1         0     A             300          SER        CA -32.577999 -10.816
# 2         0     A             300          SER         C -31.959000  -9.416
# 3         0     A             300          SER         O -31.073000  -9.017
# 4         0     A             300          SER        CB -32.813000 -11.463
# ...     ...   ...             ...          ...       ...        ...     ...
# 2360      0     N               1          UNK         I   3.866000   3.423
# 2361      0     N               1          UNK         S  -5.031000   8.821
# 2362      0     N               1          UNK         H  -5.673000  15.211
# 2363      0     N               1          UNK        HN  -5.527000  10.102
# 2364      0     N               1          UNK        HO -10.233000   7.633
#
#            Z  Occupancy  B_Factor
# 0     -9.074        1.0     43.64
# 1     -9.810        1.0     41.55
# 2     -9.965        1.0     40.15
# 3     -9.184        1.0     32.47
# 4    -11.182        1.0     44.67
# ...      ...        ...       ...
# 2360 -24.850        0.0      0.00
# 2361 -14.983        0.0      0.00
# 2362 -12.908        0.0      0.00
# 2363 -13.140        1.0      0.00
# 2364 -14.997        1.0      0.00
#
# [2365 rows x 10 columns]

# %%
pdb_4pld_df = df[(df['Chain'] == 'A') & (df['Atom_Name'] == 'CA')]
pdb_4pld_df
# Out:
#       Model Chain  Residue_Number Residue_Name Atom_Name          X  \
# 1         0     A             300          SER        CA -32.577999
# 8         0     A             301          ILE        CA -31.952999
# 17        0     A             302          PRO        CA -34.129002
# 24        0     A             303          HIS        CA -35.530998
# 37        0     A             304          LEU        CA -34.115002
# ...     ...   ...             ...          ...       ...        ...
# 2306      0     A             534          GLU        CA -12.510000
# 2316      0     A             535          MET        CA -14.620000
# 2325      0     A             536          LEU        CA -12.525000
# 2334      0     A             537          HIS        CA -12.824000
# 2347      0     A             538          ALA        CA -16.462999
#
#               Y       Z  Occupancy  B_Factor
# 1    -10.816000  -9.810        1.0     41.55
# 8     -7.309000 -11.185        1.0     24.73
# 17    -4.229000 -10.633        1.0     19.68
# 24    -2.759000 -13.824        1.0     19.13
# 37     0.612000 -12.842        1.0     16.01
# ...         ...     ...        ...       ...
# 2306  25.766001 -15.862        1.0     18.82
# 2316  23.462999 -13.653        1.0     17.52
# 2325  24.528000 -10.673        1.0     21.81
# 2334  28.228001 -11.535        1.0     26.22
# 2347  27.223000 -11.166        1.0     38.03
#
# [239 rows x 10 columns]

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Specify the path to your tab-separated file
tsv_file = '/content/drive/My Drive/LRH1-Drug-Screening/data/4pld.cif_ringEdges'

# Read the tab-separated file into a DataFrame
df = pd.read_csv(tsv_file, sep='\t')
df
# Out:
#          NodeId1  Interaction      NodeId2  Distance   Angle  Energy Atom1  \
# 0    A:300:_:SER  HBOND:MC_SC  A:487:_:CYS     4.110  43.468    17.0     O
# 1    A:301:_:ILE    VDW:SC_SC  A:306:_:LEU     4.062     NaN     6.0   CD1
# 2    A:301:_:ILE    VDW:SC_SC  A:309:_:LEU     3.965     NaN     6.0   CD1
# 3    A:301:_:ILE    VDW:SC_SC  A:446:_:ARG     3.778     NaN     6.0   CD1
# 4    A:302:_:PRO  HBOND:MC_MC  A:305:_:ILE     2.961  39.047    17.0     O
# ..           ...          ...          ...       ...     ...     ...   ...
# 737  A:533:_:ILE  HBOND:MC_MC  A:537:_:HIS     2.738  13.786    17.0     O
# 738  A:533:_:ILE  HBOND:MC_MC  A:538:_:ALA     4.812  41.233    17.0     O
# 739  A:534:_:GLU  HBOND:MC_MC  A:537:_:HIS     3.358  53.897    17.0     O
# 740  A:534:_:GLU  HBOND:MC_MC  A:538:_:ALA     3.103  18.503    17.0     O
# 741  A:535:_:MET  HBOND:MC_MC  A:538:_:ALA     3.192  50.362    17.0     O
#
#     Atom2        Donor Positive Cation Orientation  Model
# 0      SG  A:487:_:CYS      NaN    NaN         NaN      1
# 1     CD1          NaN      NaN    NaN         NaN      1
# 2     CD1          NaN      NaN    NaN         NaN      1
# 3      CG          NaN      NaN    NaN         NaN      1
# 4       N  A:305:_:ILE      NaN    NaN         NaN      1
# ..    ...          ...      ...    ...         ...    ...
# 737     N  A:537:_:HIS      NaN    NaN         NaN      1
# 738     N  A:538:_:ALA      NaN    NaN         NaN      1
# 739     N  A:537:_:HIS      NaN    NaN         NaN      1
# 740     N  A:538:_:ALA      NaN    NaN         NaN      1
# 741     N  A:538:_:ALA      NaN    NaN         NaN      1
#
# [742 rows x 13 columns]

# %%
filtered_df = df[df['NodeId1'].str.contains('^A:') & (df['NodeId2'].str.contains('^A:'))].copy()
filtered_df['source'] = filtered_df['NodeId1'].str.extract(r'(\d+)').astype(int)
filtered_df['target'] = filtered_df['NodeId2'].str.extract(r'(\d+)').astype(int)
ring_4pld_df = filtered_df[['source','target']]
ring_4pld_df
# Out:
#      source  target
# 0       300     487
# 1       301     306
# 2       301     309
# 3       301     446
# 4       302     305
# ..      ...     ...
# 737     533     537
# 738     533     538
# 739     534     537
# 740     534     538
# 741     535     538
#
# [723 rows x 2 columns]

# %%
# Merge df1 and df2 on 'ID' column
merged_df = pd.merge(ring_4pld_df, pdb_4pld_df[['Residue_Number', 'X', 'Y', 'Z']], left_on='source', right_on='Residue_Number', how='left')
merged_df.rename(columns={'X': 'X1','Y': 'Y1','Z': 'Z1'}, inplace=True)

merged_df2 = pd.merge(merged_df, pdb_4pld_df[['Residue_Number', 'X', 'Y', 'Z']], left_on='target', right_on='Residue_Number', how='left')
merged_df2.rename(columns={'X': 'X2','Y': 'Y2','Z': 'Z2'}, inplace=True)

edgelist_4pld_coords = merged_df2[['source','target','X1','Y1','Z1','X2','Y2','Z2']]
edgelist_4pld_coords
# Out:
#      source  target         X1         Y1      Z1         X2         Y2  \
# 0       300     487 -32.577999 -10.816000  -9.810 -30.712999 -10.222000
# 1       301     306 -31.952999  -7.309000 -11.185 -30.864000  -2.398000
# 2       301     309 -31.952999  -7.309000 -11.185 -26.664000   0.070000
# 3       301     446 -31.952999  -7.309000 -11.185 -24.549000  -2.778000
# 4       302     305 -34.129002  -4.229000 -10.633 -30.547001  -0.675000
# ..      ...     ...        ...        ...     ...        ...        ...
# 718     533     537  -9.398000  24.170000 -14.303 -12.824000  28.228001
# 719     533     538  -9.398000  24.170000 -14.303 -16.462999  27.223000
# 720     534     537 -12.510000  25.766001 -15.862 -12.824000  28.228001
# 721     534     538 -12.510000  25.766001 -15.862 -16.462999  27.223000
# 722     535     538 -14.620000  23.462999 -13.653 -16.462999  27.223000
#
#             Z2
# 0    -3.394000
# 1   -15.988000
# 2   -17.334999
# 3   -11.103000
# 4   -12.625000
# ..         ...
# 718 -11.535000
# 719 -11.166000
# 720 -11.535000
# 721 -11.166000
# 722 -11.166000
#
# [723 rows x 8 columns]

# %%
# !pip install py3dmol

import pandas as pd
import py3Dmol
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)

df = edgelist_1yok_coords

view = py3Dmol.view(query='pdb:1YOK', width=1200, height=800)
chA = {'chain':'A'}
chB = {'chain':'B'}
view.addSurface(py3Dmol.VDW,{'opacity':0.6,'color':'white'}, chA)
view.setStyle(chA,{'cartoon': {'color':'white'}})
view.setStyle(chB,{'': {'color':None}})
view.setHoverable({},True,'''function(atom,viewer,event,container) {
                   if(!atom.label) {
                    atom.label = viewer.addLabel(atom.resn+":"+atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black'});
                   }}''',
               '''function(atom,viewer) {
                   if(atom.label) {
                    viewer.removeLabel(atom.label);
                    delete atom.label;
                   }
                }''')



resset = [300,400,401,402,403,404]
for i in resset:
    view.addStyle({'chain':'A','resi': i},{'cartoon':{'color':'red'}})

for i in range(len(df)):

    view.addCylinder(
        {'start':dict(x=df.iloc[i][2],y=df.iloc[i][3],z=df.iloc[i][4]),
        'end':dict(x=df.iloc[i][5],y=df.iloc[i][6],z=df.iloc[i][7]),
        'radius':0.12,
        'fromCap':1,
        'toCap':1,
        'color':'red',
        'dashes':False
        }
    )

view.render()

html = view._make_html()
with open('1yok_view.html', 'w') as f:
    f.write(html)

# %%
# !pip install py3dmol

import pandas as pd
import py3Dmol

df = edgelist_1yok_coords

view = py3Dmol.view(query='pdb:1YOK', width=2000, height=1000)
chA = {'chain':'A'}
chB = {'chain':'B'}
view.addSurface(py3Dmol.VDW,{'opacity':0.6,'color':'white'}, chA)
view.setStyle(chA,{'cartoon': {'color':'white'}})
view.setStyle(chB,{'': {'color':None}})
view.setHoverable({},True,'''function(atom,viewer,event,container) {
                   if(!atom.label) {
                    atom.label = viewer.addLabel(atom.resn+":"+atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black'});
                   }}''',
               '''function(atom,viewer) {
                   if(atom.label) {
                    viewer.removeLabel(atom.label);
                    delete atom.label;
                   }
                }''')



resset = [300,400,401,402,403,404]
for i in resset:
    view.addStyle({'chain':'A','resi': i},{'cartoon':{'color':'red'}})

for i in range(len(df)):

    view.addCylinder(
        {'start':dict(x=df.iloc[i][2],y=df.iloc[i][3],z=df.iloc[i][4]),
        'end':dict(x=df.iloc[i][5],y=df.iloc[i][6],z=df.iloc[i][7]),
        'radius':0.12,
        'fromCap':1,
        'toCap':1,
        'color':'red',
        'dashes':False
        }
    )

view.render()
# Out:
# Requirement already satisfied: py3dmol in /usr/local/lib/python3.10/dist-packages (2.3.0)
# <div id="3dmolviewer_17233454658005629"  style="position: relative; width: 2000px; height: 1000px;">
#         <p id="3dmolwarning_17233454658005629" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.3.0/3Dmol-min.js');
# }
#
# var viewer_17233454658005629 = null;
# var warn = document.getElementById("3dmolwarning_17233454658005629");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17233454658005629 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17233454658005629"),{backgroundColor:"white"});
# $3Dmol.download("pdb:1YOK", viewer_17233454658005629, {}, function() {
# viewer_17233454658005629.zoomTo();
# 	viewer_17233454658005629.addSurface(1,{"opacity": 0.6, "color": "white"},{"chain": "A"});
# 	viewer_17233454658005629.setStyle({"chain": "A"},{"cartoon": {"color": "white"}});
# 	viewer_17233454658005629.setStyle({"chain": "B"},{"": {"color": null}});
# 	viewer_17233454658005629.setHoverable({},true,"function(atom,viewer,event,container) {\n                   if(!atom.label) {\n                    atom.label = viewer.addLabel(atom.resn+\":\"+atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black'});\n                   }}","function(atom,viewer) { \n                   if(atom.label) {\n                    viewer.removeLabel(atom.label);\n                    delete atom.label;\n                   }\n                }");
# 	viewer_17233454658005629.addStyle({"chain": "A", "resi": 300},{"cartoon": {"color": "red"}});
# 	viewer_17233454658005629.addStyle({"chain": "A", "resi": 400},{"cartoon": {"color": "red"}});
# 	viewer_17233454658005629.addStyle({"chain": "A", "resi": 401},{"cartoon": {"color": "red"}});
# 	viewer_17233454658005629.addStyle({"chain": "A", "resi": 402},{"cartoon": {"color": "red"}});
# 	viewer_17233454658005629.addStyle({"chain": "A", "resi": 403},{"cartoon": {"color": "red"}});
# 	viewer_17233454658005629.addStyle({"chain": "A", "resi": 404},{"cartoon": {"color": "red"}});
# 	viewer_17233454658005629.addCylinder({"start": {"x": 27.73900032043457, "y": 54.654998779296875, "z": 33.64899826049805}, "end": {"x": 33.22700119018555, "y": 51.904998779296875, "z": 30.902000427246094}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_17233454658005629.addCylinder({"start": {"x": 25.391000747680664, "y": 51.7239990234375, "z": 32.97100067138672}, "end": {"x": 21.167999267578125, "y": 47.05500030517578, "z": 30.94499969482422}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_17233454658005629.addCylinder({"start": {"x": 25.391000747680664, "y": 51.7239990234375, "z": 32.97100067138672}, "end": {"x": 19.78499984741211, "y": 48.26499938964844, "z": 34.279998779296875}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_17233454658005629.addCylinder({"start": {"x": 25.391000747680664, "y": 51.7239990234375, "z": 32.97100067138672}, "end": {"x": 26.35099983215332, "y": 43.93000030517578, "z": 32.92399978637695}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_17233454658005629.addCylinder({"start": {"x": 22.9950008392334, "y": 52.35100173950195, "z": 30.024999618530273}, "end": {"x": 21.167999267578125, "y": 47.05500030517578, "z": 30.94499969482422}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_17233454658005629.addCylinder({"start": {"x": 22.9950008392334, "y": 52.35100173950195, "z": 30.024999618530273}, "end": {"x": 28.382999420166016, "y": 50.33599853515625, "z": 27.739999771118164}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_17233454658005629.addCylinder({"start": {"x": 18.42300033569336, "y": 48.92900085449219, "z": 29.101999282836914}, "end": {"x": 16.347999572753906, "y": 46.888999938964844, "z": 33.36800003051758}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_17233454658005629.addCylinder({"start": {"x": 18.42300033569336, "y": 48.92900085449219, "z": 29.101999282836914}, "end": {"x": 17.607999801635742, "y": 43.45600128173828, "z": 32.29899978637695}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_17233454658005629.addCylinder({"start": {"x": 18.42300033569336, "y": 48.92900085449219, "z": 29.101999282836914}, "end": {"x": 10.383999824523926, "y": 41.757999420166016, "z": 26.797000885009766}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_17233454658005629.addCylinder({"start": {"x": 18.42300033569336, "y": 48.92900085449219, "z": 29.101999282836914}, "end": {"x": 18.628999710083008, "y": 47.32699966430664, "z": 21.138999938964844}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_17233454658005629.addCylinder({"start": {"x": 18.42300033569336, "y": 48.92900085449219, "z": 29.101999282836914}, "end": {"x": 20.65999984741211, "y": 45.16400146484375, "z": 23.520999908447266}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_17233454658005629.addCylinder({"start": {"x": 18.42300033569336, "y": 48.92900085449219, "z": 29.101999282836914}, "end": {"x": 23.29599952697754, "y": 49.09700012207031, "z": 24.649999618530273}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_17233454658005629.addCylinder({"start": {"x": 21.167999267578125, "y": 47.05500030517578, "z": 30.94499969482422}, "end": {"x": 19.97800064086914, "y": 43.54800033569336, "z": 35.275001525878906}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_17233454658005629.addCylinder({"start": {"x": 21.167999267578125, "y": 47.05500030517578, "z": 30.94499969482422}, "end": {"x": 26.35099983215332, "y": 43.93000030517578, "z": 32.92399978637695}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_17233454658005629.addCylinder({"start": {"x": 21.167999267578125, "y": 47.05500030517578, "z": 30.94499969482422}, "end": {"x": 23.475000381469727, "y": 41.44599914550781, "z": 27.54800033569336}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_17233454658005629.addCylinder({"start": {"x": 21.167999267578125, "y": 47.05500030517578, "z": 30.94499969482422}, "end": {"x": 23.29599952697754, "y": 49.09700012207031, "z": 24.649999618530273}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_17233454658005629.addCylinder({"start": {"x": 21.167999267578125, "y": 47.05500030517578, "z": 30.94499969482422}, "end": {"x": 28.382999420166016, "y": 50.33599853515625, "z": 27.739999771118164}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_17233454658005629.addCylinder({"start": {"x": 19.78499984741211, "y": 48.26499938964844, "z": 34.279998779296875}, "end": {"x": 19.97800064086914, "y": 43.54800033569336, "z": 35.275001525878906}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_17

# %%
df = edgelist_4pld_coords

view = py3Dmol.view(query='pdb:4PLD', width=2000, height=1000)
chA = {'chain':'A'}
chB = {'chain':'B'}
view.addSurface(py3Dmol.VDW,{'opacity':0.6,'color':'white'}, chA)
view.setStyle(chA,{'cartoon': {'color':'white'}})
view.setStyle(chB,{'': {'color':None}})
view.setHoverable({},True,'''function(atom,viewer,event,container) {
                   if(!atom.label) {
                    atom.label = viewer.addLabel(atom.resn+":"+atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black'});
                   }}''',
               '''function(atom,viewer) {
                   if(atom.label) {
                    viewer.removeLabel(atom.label);
                    delete atom.label;
                   }
                }''')



resset = [300,400,401,402,403,404]
for i in resset:
    view.addStyle({'chain':'A','resi': i},{'cartoon':{'color':'green'}})

for i in range(len(df)):

    view.addCylinder(
        {'start':dict(x=df.iloc[i][2],y=df.iloc[i][3],z=df.iloc[i][4]),
        'end':dict(x=df.iloc[i][5],y=df.iloc[i][6],z=df.iloc[i][7]),
        'radius':0.12,
        'fromCap':1,
        'toCap':1,
        'color':'green',
        'dashes':False
        }
    )

view.render()
# Out:
# <div id="3dmolviewer_17233454399393141"  style="position: relative; width: 2000px; height: 1000px;">
#         <p id="3dmolwarning_17233454399393141" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.3.0/3Dmol-min.js');
# }
#
# var viewer_17233454399393141 = null;
# var warn = document.getElementById("3dmolwarning_17233454399393141");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17233454399393141 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17233454399393141"),{backgroundColor:"white"});
# $3Dmol.download("pdb:4PLD", viewer_17233454399393141, {}, function() {
# viewer_17233454399393141.zoomTo();
# 	viewer_17233454399393141.addSurface(1,{"opacity": 0.6, "color": "white"},{"chain": "A"});
# 	viewer_17233454399393141.setStyle({"chain": "A"},{"cartoon": {"color": "white"}});
# 	viewer_17233454399393141.setStyle({"chain": "B"},{"": {"color": null}});
# 	viewer_17233454399393141.setHoverable({},true,"function(atom,viewer,event,container) {\n                   if(!atom.label) {\n                    atom.label = viewer.addLabel(atom.resn+\":\"+atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black'});\n                   }}","function(atom,viewer) { \n                   if(atom.label) {\n                    viewer.removeLabel(atom.label);\n                    delete atom.label;\n                   }\n                }");
# 	viewer_17233454399393141.addStyle({"chain": "A", "resi": 300},{"cartoon": {"color": "green"}});
# 	viewer_17233454399393141.addStyle({"chain": "A", "resi": 400},{"cartoon": {"color": "green"}});
# 	viewer_17233454399393141.addStyle({"chain": "A", "resi": 401},{"cartoon": {"color": "green"}});
# 	viewer_17233454399393141.addStyle({"chain": "A", "resi": 402},{"cartoon": {"color": "green"}});
# 	viewer_17233454399393141.addStyle({"chain": "A", "resi": 403},{"cartoon": {"color": "green"}});
# 	viewer_17233454399393141.addStyle({"chain": "A", "resi": 404},{"cartoon": {"color": "green"}});
# 	viewer_17233454399393141.addCylinder({"start": {"x": -32.577999114990234, "y": -10.815999984741211, "z": -9.8100004196167}, "end": {"x": -30.71299934387207, "y": -10.222000122070312, "z": -3.3940000534057617}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "green", "dashes": false});
# 	viewer_17233454399393141.addCylinder({"start": {"x": -31.952999114990234, "y": -7.309000015258789, "z": -11.1850004196167}, "end": {"x": -30.86400032043457, "y": -2.3980000019073486, "z": -15.98799991607666}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "green", "dashes": false});
# 	viewer_17233454399393141.addCylinder({"start": {"x": -31.952999114990234, "y": -7.309000015258789, "z": -11.1850004196167}, "end": {"x": -26.663999557495117, "y": 0.07000000029802322, "z": -17.334999084472656}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "green", "dashes": false});
# 	viewer_17233454399393141.addCylinder({"start": {"x": -31.952999114990234, "y": -7.309000015258789, "z": -11.1850004196167}, "end": {"x": -24.548999786376953, "y": -2.7780001163482666, "z": -11.102999687194824}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "green", "dashes": false});
# 	viewer_17233454399393141.addCylinder({"start": {"x": -34.12900161743164, "y": -4.229000091552734, "z": -10.633000373840332}, "end": {"x": -30.547000885009766, "y": -0.675000011920929, "z": -12.625}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "green", "dashes": false});
# 	viewer_17233454399393141.addCylinder({"start": {"x": -34.12900161743164, "y": -4.229000091552734, "z": -10.633000373840332}, "end": {"x": -30.86400032043457, "y": -2.3980000019073486, "z": -15.98799991607666}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "green", "dashes": false});
# 	viewer_17233454399393141.addCylinder({"start": {"x": -34.12900161743164, "y": -4.229000091552734, "z": -10.633000373840332}, "end": {"x": -31.94300079345703, "y": 0.968999981880188, "z": -17.448999404907227}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "green", "dashes": false});
# 	viewer_17233454399393141.addCylinder({"start": {"x": -34.12900161743164, "y": -4.229000091552734, "z": -10.633000373840332}, "end": {"x": -32.80799865722656, "y": -0.35100001096725464, "z": -6.046000003814697}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "green", "dashes": false});
# 	viewer_17233454399393141.addCylinder({"start": {"x": -34.12900161743164, "y": -4.229000091552734, "z": -10.633000373840332}, "end": {"x": -29.947999954223633, "y": -5.535999774932861, "z": -5.545000076293945}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "green", "dashes": false});
# 	viewer_17233454399393141.addCylinder({"start": {"x": -35.53099822998047, "y": -2.759000062942505, "z": -13.824000358581543}, "end": {"x": -30.86400032043457, "y": -2.3980000019073486, "z": -15.98799991607666}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "green", "dashes": false});
# 	viewer_17233454399393141.addCylinder({"start": {"x": -35.53099822998047, "y": -2.759000062942505, "z": -13.824000358581543}, "end": {"x": -31.94300079345703, "y": 0.968999981880188, "z": -17.448999404907227}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "green", "dashes": false});
# 	viewer_17233454399393141.addCylinder({"start": {"x": -35.53099822998047, "y": -2.759000062942505, "z": -13.824000358581543}, "end": {"x": -28.961000442504883, "y": 2.759999990463257, "z": -15.9350004196167}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "green", "dashes": false});
# 	viewer_17233454399393141.addCylinder({"start": {"x": -34.1150016784668, "y": 0.6119999885559082, "z": -12.842000007629395}, "end": {"x": -31.94300079345703, "y": 0.968999981880188, "z": -17.448999404907227}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "green", "dashes": false});
# 	viewer_17233454399393141.addCylinder({"start": {"x": -34.1150016784668, "y": 0.6119999885559082, "z": -12.842000007629395}, "end": {"x": -28.961000442504883, "y": 2.759999990463257, "z": -15.9350004196167}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "green", "dashes": false});
# 	viewer_17233454399393141.addCylinder({"start": {"x": -34.1150016784668, "y": 0.6119999885559082, "z": -12.842000007629395}, "end": {"x": -26.663999557495117, "y": 0.07000000029802322, "z": -17.334999084472656}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "green", "dashes": false});
# 	viewer_17233454399393141.addCylinder({"start": {"x": -34.1150016784668, "y": 0.6119999885559082, "z": -12.842000007629395}, "end": {"x": -32.882999420166016, "y": 11.059000015258789, "z": -16.4950008392334}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "green", "dashes": false});
# 	viewer_17233454399393141.addCylinder({"start": {"x": -34.1150016784668, "y": 0.6119999885559082, "z": -12.842000007629395}, "end": {"x": -35.30699920654297, "y": 5.168000221252441, "z": -6.324999809265137}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "green", "dashes": false});
# 	viewer_17233454399393141.addCylinder({"start": {"x": -34.1150016784668, "y": 0.6119999885559082, "z": -12.842000007629395}, "end": {"x": -31.625, "y": 4.420000076293

# %%
import pandas as pd
import py3Dmol
from IPython.display import display, HTML

df_1yok = edgelist_1yok_coords
df_4pld = edgelist_4pld_coords

# Function to generate the HTML for embedding the viewer
def generate_viewer_html(pdb_id, df, resset, color, chain_color, width=900, height=900):
    view = py3Dmol.view(query=f'pdb:{pdb_id}', width=width, height=height)
    chA = {'chain': 'A'}
    chB = {'chain': 'B'}
    view.addSurface(py3Dmol.VDW, {'opacity': 0.6, 'color': 'white'}, chA)
    view.setStyle(chA, {'cartoon': {'color': chain_color}})
    view.setStyle(chB, {'cartoon': {'color': chain_color}})
    view.setHoverable({}, True, '''function(atom,viewer,event,container) {
                       if(!atom.label) {
                        atom.label = viewer.addLabel(atom.resn+":"+atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black'});
                       }}''',
                   '''function(atom,viewer) {
                       if(atom.label) {
                        viewer.removeLabel(atom.label);
                        delete atom.label;
                       }
                    }''')

    for i in resset:
        view.addStyle({'chain': 'A', 'resi': i}, {'cartoon': {'color': color}})

    for i in range(len(df)):
        view.addCylinder(
            {'start': dict(x=df.iloc[i][2], y=df.iloc[i][3], z=df.iloc[i][4]),
             'end': dict(x=df.iloc[i][5], y=df.iloc[i][6], z=df.iloc[i][7]),
             'radius': 0.12,
             'fromCap': 1,
             'toCap': 1,
             'color': color,
             'dashes': False
             }
        )

    return view

# Create the HTML for both viewers
viewer1_html = generate_viewer_html('1YOK', df_1yok, [300, 400, 401, 402, 403, 404], 'red', 'white')._make_html()
viewer2_html = generate_viewer_html('4PLD', df_4pld, [500, 600, 601, 602, 603, 604], 'green', 'white')._make_html()

# Display both viewers side by side
html = f"""
<div style="display: flex; justify-content: space-around;">
    <div>{viewer1_html}</div>
    <div>{viewer2_html}</div>
</div>
"""

display(HTML(html))
# Out:
# <div style="display: flex; justify-content: space-around;">
#     <div><div id="3dmolviewer_1723345623847333"  style="position: relative; width: 900px; height: 900px;">
#         <p id="3dmolwarning_1723345623847333" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.3.0/3Dmol-min.js');
# }
#
# var viewer_1723345623847333 = null;
# var warn = document.getElementById("3dmolwarning_1723345623847333");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1723345623847333 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1723345623847333"),{backgroundColor:"white"});
# $3Dmol.download("pdb:1YOK", viewer_1723345623847333, {}, function() {
# viewer_1723345623847333.zoomTo();
# 	viewer_1723345623847333.addSurface(1,{"opacity": 0.6, "color": "white"},{"chain": "A"});
# 	viewer_1723345623847333.setStyle({"chain": "A"},{"cartoon": {"color": "white"}});
# 	viewer_1723345623847333.setStyle({"chain": "B"},{"cartoon": {"color": "white"}});
# 	viewer_1723345623847333.setHoverable({},true,"function(atom,viewer,event,container) {\n                       if(!atom.label) {\n                        atom.label = viewer.addLabel(atom.resn+\":\"+atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black'});\n                       }}","function(atom,viewer) { \n                       if(atom.label) {\n                        viewer.removeLabel(atom.label);\n                        delete atom.label;\n                       }\n                    }");
# 	viewer_1723345623847333.addStyle({"chain": "A", "resi": 300},{"cartoon": {"color": "red"}});
# 	viewer_1723345623847333.addStyle({"chain": "A", "resi": 400},{"cartoon": {"color": "red"}});
# 	viewer_1723345623847333.addStyle({"chain": "A", "resi": 401},{"cartoon": {"color": "red"}});
# 	viewer_1723345623847333.addStyle({"chain": "A", "resi": 402},{"cartoon": {"color": "red"}});
# 	viewer_1723345623847333.addStyle({"chain": "A", "resi": 403},{"cartoon": {"color": "red"}});
# 	viewer_1723345623847333.addStyle({"chain": "A", "resi": 404},{"cartoon": {"color": "red"}});
# 	viewer_1723345623847333.addCylinder({"start": {"x": 27.73900032043457, "y": 54.654998779296875, "z": 33.64899826049805}, "end": {"x": 33.22700119018555, "y": 51.904998779296875, "z": 30.902000427246094}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_1723345623847333.addCylinder({"start": {"x": 25.391000747680664, "y": 51.7239990234375, "z": 32.97100067138672}, "end": {"x": 21.167999267578125, "y": 47.05500030517578, "z": 30.94499969482422}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_1723345623847333.addCylinder({"start": {"x": 25.391000747680664, "y": 51.7239990234375, "z": 32.97100067138672}, "end": {"x": 19.78499984741211, "y": 48.26499938964844, "z": 34.279998779296875}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_1723345623847333.addCylinder({"start": {"x": 25.391000747680664, "y": 51.7239990234375, "z": 32.97100067138672}, "end": {"x": 26.35099983215332, "y": 43.93000030517578, "z": 32.92399978637695}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_1723345623847333.addCylinder({"start": {"x": 22.9950008392334, "y": 52.35100173950195, "z": 30.024999618530273}, "end": {"x": 21.167999267578125, "y": 47.05500030517578, "z": 30.94499969482422}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_1723345623847333.addCylinder({"start": {"x": 22.9950008392334, "y": 52.35100173950195, "z": 30.024999618530273}, "end": {"x": 28.382999420166016, "y": 50.33599853515625, "z": 27.739999771118164}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_1723345623847333.addCylinder({"start": {"x": 18.42300033569336, "y": 48.92900085449219, "z": 29.101999282836914}, "end": {"x": 16.347999572753906, "y": 46.888999938964844, "z": 33.36800003051758}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_1723345623847333.addCylinder({"start": {"x": 18.42300033569336, "y": 48.92900085449219, "z": 29.101999282836914}, "end": {"x": 17.607999801635742, "y": 43.45600128173828, "z": 32.29899978637695}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_1723345623847333.addCylinder({"start": {"x": 18.42300033569336, "y": 48.92900085449219, "z": 29.101999282836914}, "end": {"x": 10.383999824523926, "y": 41.757999420166016, "z": 26.797000885009766}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_1723345623847333.addCylinder({"start": {"x": 18.42300033569336, "y": 48.92900085449219, "z": 29.101999282836914}, "end": {"x": 18.628999710083008, "y": 47.32699966430664, "z": 21.138999938964844}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_1723345623847333.addCylinder({"start": {"x": 18.42300033569336, "y": 48.92900085449219, "z": 29.101999282836914}, "end": {"x": 20.65999984741211, "y": 45.16400146484375, "z": 23.520999908447266}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_1723345623847333.addCylinder({"start": {"x": 18.42300033569336, "y": 48.92900085449219, "z": 29.101999282836914}, "end": {"x": 23.29599952697754, "y": 49.09700012207031, "z": 24.649999618530273}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_1723345623847333.addCylinder({"start": {"x": 21.167999267578125, "y": 47.05500030517578, "z": 30.94499969482422}, "end": {"x": 19.97800064086914, "y": 43.54800033569336, "z": 35.275001525878906}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_1723345623847333.addCylinder({"start": {"x": 21.167999267578125, "y": 47.05500030517578, "z": 30.94499969482422}, "end": {"x": 26.35099983215332, "y": 43.93000030517578, "z": 32.92399978637695}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_1723345623847333.addCylinder({"start": {"x": 21.167999267578125, "y": 47.05500030517578, "z": 30.94499969482422}, "end": {"x": 23.475000381469727, "y": 41.44599914550781, "z": 27.54800033569336}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_1723345623847333.addCylinder({"start": {"x": 21.167999267578125, "y": 47.05500030517578, "z": 30.94499969482422}, "end": {"x": 23.29599952697754, "y": 49.09700012207031, "z": 24.649999618530273}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_1723345623847333.addCylinder({"start": {"x": 21.167999267578125, "y": 47.05500030517578, "z": 30.94499969482422}, "end": {"x": 28.382999420166016, "y": 50.33599853515625, "z": 27.739999771118164}, "radius": 0.12, "fromCap": 1, "toCap": 1, "color": "red", "dashes": false});
# 	viewer_1723345623847333.addCylinder({"start": {"x": 19.78499984741211, "y": 48.26499938964844, "z": 34.279998779296875}, "end": {"x": 19.97800064086914, "y": 43.54800033569336, "z": 35.275001525878906}, "radius": 0.1
